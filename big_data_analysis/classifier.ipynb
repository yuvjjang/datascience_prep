# %%
# 데이터 설명 : 고객의 신상정보 데이터를 통한 회사 서비스 이탈 예측 (종속변수 : Exited)
# x_train : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv
# y_train : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv
# x_test : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv
# x_label(평가용) : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv
# 데이터 출처 : https://www.kaggle.com/shubh0799/churn-modelling 에서 변형

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv")


display(x_train.head())
display(y_train.head())
# Out:
#    CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15799217   Zetticci          791   Germany  Female   35       7
# 1    15748986    Bischof          705   Germany    Male   42       8
# 2    15722004     Hsiung          543    France  Female   31       4
# 3    15780966  Pritchard          709    France  Female   32       2
# 4    15636731      Ts'ai          714   Germany  Female   36       1
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0   52436.20              1          1               0        161051.75
# 1  166685.92              2          1               1         55313.51
# 2  138317.94              1          0               0         61843.73
# 3       0.00              2          0               0        109681.29
# 4  101609.01              2          1               1           447.73
#    CustomerId  Exited
# 0    15799217       0
# 1    15748986       0
# 2    15722004       0
# 3    15780966       0
# ...

# %%
x_test.head()
# Out:
#    CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15601012     Abdullah          802    France  Female   60       3
# 1    15734762     Ignatiev          602    France  Female   56       3
# 2    15586757  Anenechukwu          801    France  Female   32       4
# 3    15590888         Wade          693     Spain  Female   34      10
# 4    15726087        Ch'in          592    France  Female   62       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0   92887.06              1          1               0         39473.63
# 1  115895.22              3          1               0          4176.17
# 2   75170.54              1          1               1         37898.50
# 3  107556.06              2          0               0        154631.35
# 4       0.00              1          1               1        100941.57

# %%
(x_train.isna()+0).sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %%
(y_train.isna()+0).sum()
# Out:
# CustomerId    0
# Exited        0
# dtype: int64

# %%
len(x_train.Surname.unique())
# Out:
# 2289

# %%
len(x_test.Surname.unique())
# Out:
# 1688

# %%
len(set(x_train.Surname.unique())-set(x_test.Surname.unique()))
# Out:
# 1244

# %%
def x_preprocessing(x_train):
    x_train = pd.get_dummies(data=x_train, columns=["Geography"], drop_first=True)
    x_train.Gender = x_train.Gender.apply(lambda x: 0 if x.lower() == 'female' else 1)
    x_train.drop(columns=['Surname'],inplace=True)
    return x_train

# %%
#x_train.Gender = x_train.Gender.apply(lambda x: 0 if x.lower() == 'female' else 1)

# %%
#x_train = pd.get_dummies(data=x_train, columns=["Surname","Geography"], drop_first=True)

# %%
x_train_modi = x_preprocessing(x_train)

# %%
x_train_modi
# Out:
#       CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0       15799217          791       0   35       7   52436.20              1
# 1       15748986          705       1   42       8  166685.92              2
# 2       15722004          543       0   31       4  138317.94              1
# 3       15780966          709       0   32       2       0.00              2
# 4       15636731          714       0   36       1  101609.01              2
# ...          ...          ...     ...  ...     ...        ...            ...
# 6494    15702806          696       1   24       9       0.00              1
# 6495    15674179          513       1   34       7   60515.13              1
# 6496    15790204          663       0   22       9       0.00              1
# 6497    15690772          635       0   48       2       0.00              2
# 6498    15706463          597       0   36       9       0.00              2
#
# ...

# %%
x_train
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15799217   Zetticci          791   Germany  Female   35       7
# 1       15748986    Bischof          705   Germany    Male   42       8
# 2       15722004     Hsiung          543    France  Female   31       4
# 3       15780966  Pritchard          709    France  Female   32       2
# 4       15636731      Ts'ai          714   Germany  Female   36       1
# ...          ...        ...          ...       ...     ...  ...     ...
# 6494    15702806     Martin          696     Spain    Male   24       9
# 6495    15674179  Vorobyova          513   Germany    Male   34       7
# 6496    15790204      Myers          663     Spain  Female   22       9
# 6497    15690772     Hughes          635     Spain  Female   48       2
# 6498    15706463       Yang          597    France  Female   36       9
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(x_train_modi, y_train, train_size=0.7)

# %%
df_train_x
# Out:
#       CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 3186    15741078          736       1   54       7  111729.47              2
# 5621    15610753          581       1   28       3  104367.50              1
# 1653    15611191          505       0   37      10  122453.97              2
# 2403    15765902          706       1   38       5  163034.82              2
# 239     15652999          742       1   33       1  137937.95              1
# ...          ...          ...     ...  ...     ...        ...            ...
# 3562    15770435          639       0   50       6  115335.32              2
# 681     15610226          614       0   27       9  106414.57              2
# 2205    15717984          477       1   47       9  144900.58              1
# 2425    15750874          676       1   31       3   78990.15              1
# 4071    15574842          653       0   25       2  158266.42              3
#
# ...

# %%
df_train_y
# Out:
#       CustomerId  Exited
# 3186    15741078       0
# 5621    15610753       0
# 1653    15611191       0
# 2403    15765902       0
# 239     15652999       0
# ...          ...     ...
# 3562    15770435       0
# 681     15610226       0
# 2205    15717984       1
# 2425    15750874       0
# 4071    15574842       0
#
# [4549 rows x 2 columns]

# %%
df_test_x
# Out:
#       CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 2518    15677310          761       1   62       5   98854.34              1
# 432     15768451          739       1   40       5  149131.03              3
# 4409    15566312          660       0   42       5       0.00              3
# 953     15644400          709       1   44       9  128601.98              1
# 2346    15726588          653       0   36       3       0.00              2
# ...          ...          ...     ...  ...     ...        ...            ...
# 3961    15709396          801       1   42       6       0.00              2
# 814     15763980          632       1   30       1   58668.02              1
# 103     15635500          605       1   75       2   61319.63              1
# 2850    15691808          656       1   43       7  134919.85              1
# 4928    15793854          723       1   42       2   99095.73              1
#
# ...

# %%
df_test_y
# Out:
#       CustomerId  Exited
# 2518    15677310       1
# 432     15768451       1
# 4409    15566312       1
# 953     15644400       0
# 2346    15726588       0
# ...          ...     ...
# 3961    15709396       0
# 814     15763980       0
# 103     15635500       0
# 2850    15691808       0
# 4928    15793854       0
#
# [1950 rows x 2 columns]

# %%
#이상치 제거

# %%
#from scipy.spatial.distance import mahalanobis

# %%
#scaled_columns = ['CreditScore','Age',"Balance","EstimatedSalary"]

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score

# %%
#linear classifier

# %%
from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
from statsmodels.formula.api import ols

# %%
model1 = LinearRegression().fit(X=df_train_x.iloc[:,1:], y=df_train_y.Exited)

# %%
y_predict_prob = model1.predict(X=df_test_x.iloc[:,1:])

# %%
y_predict = (model1.predict(X=df_test_x.iloc[:,1:])>0.5)+0

# %%
accuracy_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.7964102564102564

# %%
f1_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.19472616632860043

# %%
recall_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.11347517730496454

# %%
precision_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.6857142857142857

# %%
roc_auc_score(y_score=y_predict_prob, y_true=df_test_y.Exited)
# Out:
# 0.7656725822507706

# %%
#naive bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model2 = GaussianNB().fit(X=df_train_x.iloc[:,1:], y=df_train_y.Exited)

# %%
y_predict_prob = model2.predict(X=df_test_x.iloc[:,1:])

# %%
y_predict = (model2.predict(X=df_test_x.iloc[:,1:])>0.5)+0

# %%
accuracy_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.7728205128205128

# %%
f1_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.15296367112810705

# %%
recall_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.09456264775413711

# %%
precision_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.4

# %%
roc_auc_score(y_score=y_predict_prob, y_true=df_test_y.Exited)
# Out:
# 0.5276349584546717

# %%
#random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:32: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
model3 = RandomForestClassifier(n_estimators=100,random_state =23).fit(X=df_train_x.iloc[:,1:], y=df_train_y.Exited)
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:489: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_store_unique_indices = np.zeros(y.shape, dtype=np.int)
# ...

# %%
y_predict_proba = model3.predict_proba(X=df_test_x.iloc[:,1:])
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\ensemble\base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)

# %%
y_predict = model3.predict(X=df_test_x.iloc[:,1:])
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\ensemble\base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)

# %%
accuracy_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.8569230769230769

# %%
f1_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.5740458015267176

# %%
recall_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.4444444444444444

# %%
precision_score(y_pred=y_predict, y_true=df_test_y.Exited)
# Out:
# 0.8103448275862069

# %%
roc_auc_score(y_score=y_predict_prob, y_true=df_test_y.Exited)
# Out:
# 0.5276349584546717

# %%
x_test = x_preprocessing(x_test)

# %%
x_test
# Out:
#       CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0       15601012          802       0   60       3   92887.06              1
# 1       15734762          602       0   56       3  115895.22              3
# 2       15586757          801       0   32       4   75170.54              1
# 3       15590888          693       0   34      10  107556.06              2
# 4       15726087          592       0   62       5       0.00              1
# ...          ...          ...     ...  ...     ...        ...            ...
# 3496    15733966          496       0   55       4  125292.53              1
# 3497    15669994          556       0   31       1  128663.81              2
# 3498    15712403          589       0   61       1       0.00              1
# 3499    15643819          714       0   25       4       0.00              2
# 3500    15644962          745       1   21       4  137910.45              1
#
# ...

# %%
y_predict = model3.predict(X=x_test.iloc[:,1:])
# Out:
# C:\Users\yuvjj\Anaconda3\lib\site-packages\sklearn\ensemble\base.py:158: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int)

# %%
y_predict
# Out:
# array([1, 1, 0, ..., 1, 0, 0], dtype=int64)
