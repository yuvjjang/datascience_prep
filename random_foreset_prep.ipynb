# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %%
df = pd.read_csv("data/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df["AGEs"] = 0

# %%
df.loc[(df["Age"]>=30) & (df["Age"]<40),"AGEs"] = "H1"

# %%
df.loc[(df["Age"]>=40) & (df["Age"]<50),"AGEs"] = "H2"

# %%
df.loc[(df["Age"]>=50) & (df["Age"]<60),"AGEs"] = "H3"

# %%
df.loc[(df["Age"]>=60) & (df["Age"]<70),"AGEs"] = "H4"

# %%
df.loc[(df["Age"]>=70) & (df["Age"]<80),"AGEs"] = "H5"

# %%
df.loc[(df["Age"]<30) | (df["Age"]>=80),"AGEs"] = "H6"

# %%
df["AGEs"].unique()
# Out:
# array(['H3', 'H1', 'H6', 'H2', 'H4', 'H5'], dtype=object)

# %%
df.groupby("AGEs").sample(frac=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-8c9f3be74a02> in <module>
# ----> 1 df.groupby("AGEs").sample(frac=0.8)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sample' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
df.sample(frac=0.8)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 494            3       80              0              0        0   0.0
# 438            1       97             70             15        0  18.2
# 22             7      196             90              0        0  39.8
# 167            4      120             68              0        0  29.6
# 555            7      124             70             33      215  25.5
# ..           ...      ...            ...            ...      ...   ...
# 588            3      176             86             27      156  33.3
# 697            0       99              0              0        0  25.0
# 695            7      142             90             24      480  30.4
# 727            0      141             84             26        0  32.4
# 598            1      173             74              0        0  36.8
#
#      DiabetesPedigreeFunction  Age  Outcome AGEs
# 494                     0.174   22        0   H6
# 438                     0.147   21        0   H6
# 22                      0.451   41        1   H2
# 167                     0.709   34        0   H1
# 555                     0.161   37        0   H1
# ..                        ...  ...      ...  ...
# 588                     1.154   52        1   H3
# 697                     0.253   22        0   H6
# 695                     0.128   43        1   H2
# 727                     0.433   22        0   H6
# 598                     0.088   38        1   H1
#
# [614 rows x 10 columns]

# %%
df.shape
# Out:
# (768, 10)

# %%
df_train = df.groupby("AGEs").apply(func=pd.DataFrame.sample, frac=0.8, random_state=123)

# %%
df_train.shape
# Out:
# (615, 10)

# %%
df_train = df_train.reset_index(drop=True)

# %%
df_test = df.drop(index=df_train.index)

# %%
df_test.shape
# Out:
# (153, 10)

# %%
from sklearn.model_selection import train_test_split

# %%
print(pd.__version__)
# Out:
# 0.25.1

# %%
col_x = ["Glucose","BloodPressure","BMI"]

# %%
col_x_S =[x+"_S" for x in col_x]

# %%
col_x_S
# Out:
# ['Glucose_S', 'BloodPressure_S', 'BMI_S']

# %%
for param in col_x_S:
    df.loc[:,param]=0

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome AGEs  Glucose_S  BloodPressure_S  \
# 0                     0.627   50        1   H3          0                0
# 1                     0.351   31        0   H1          0                0
# 2                     0.672   32        1   H1          0                0
# 3                     0.167   21        0   H6          0                0
# 4                     2.288   33        1   H1          0                0
#
#    BMI_S
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df_scaled = StandardScaler().fit(X=df[col_x])

# %%
df.loc[:,col_x_S]=df_scaled.transform(X=df[col_x])

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome AGEs  Glucose_S  BloodPressure_S  \
# 0                     0.627   50        1   H3   0.848324         0.149641
# 1                     0.351   31        0   H1  -1.123396        -0.160546
# 2                     0.672   32        1   H1   1.943724        -0.263941
# 3                     0.167   21        0   H6  -0.998208        -0.160546
# 4                     2.288   33        1   H1   0.504055        -1.504687
#
#       BMI_S
# 0  0.204013
# 1 -0.684422
# 2 -1.103255
# 3 -0.494043
# 4  1.409746

# %%
glu_mean = df["Glucose_S"].mean()

# %%
glu_std = df["Glucose_S"].std()

# %%
upper = glu_mean+1.5*glu_std

# %%
lower = glu_mean-1.5*glu_std

# %%
upper
# Out:
# 1.5009775172102993

# %%
lower
# Out:
# -1.5009775172102993

# %%
glu_mean
# Out:
# 3.614007241618348e-18

# %%
glu_std
# Out:
# 1.0006516781401995

# %%
df_sub = df.loc[(df["Glucose_S"]>lower)&(df["Glucose_S"]<upper)]

# %%
df_sub
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome AGEs  Glucose_S  BloodPressure_S  \
# 0                       0.627   50        1   H3   0.848324         0.149641
# 1                       0.351   31        0   H1  -1.123396        -0.160546
# 3                       0.167   21        0   H6  -0.998208        -0.160546
# 4                       2.288   33        1   H1   0.504055        -1.504687
# 5                       0.201   30        0   H1  -0.153185         0.253036
# ..                        ...  ...      ...  ...        ...              ...
# 763                     0.171   63        0   H4  -0.622642         0.356432
# 764                     0.340   27        0   H6   0.034598         0.046245
# 765                     0.245   30        0   H1   0.003301         0.149641
# 766                     0.349   47        1   H2   0.159787        -0.470732
# 767                     0.315   23        0   H6  -0.873019         0.046245
#
#         BMI_S
# 0    0.204013
# 1   -0.684422
# 3   -0.494043
# 4    1.409746
# 5   -0.811341
# ..        ...
# 763  0.115169
# 764  0.610154
# 765 -0.735190
# 766 -0.240205
# 767 -0.202129
#
# [675 rows x 13 columns]

# %%
df_train = df_sub.groupby(["AGEs"]).apply(func=pd.DataFrame.sample, frac=0.8, random_state=1234)

# %%
df_train
# Out:
#           Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# AGEs
# H1   16             0      118             84             47      230  45.8
#      468            8      120              0              0        0  30.0
#      443            8      108             70              0        0  30.5
#      463            5       88             78             30        0  27.6
#      131            9      122             56              0        0  33.3
# ...               ...      ...            ...            ...      ...   ...
# H6   144            4      154             62             31      284  32.8
#      726            1      116             78             29      180  36.1
#      328            2      102             86             36      120  45.5
#      497            2       81             72             15       76  30.1
#      232            1       79             80             25       37  25.4
#
#           DiabetesPedigreeFunction  Age  Outcome AGEs  Glucose_S  \
# AGEs
# H1   16                      0.551   31        1   H1  -0.090591
#      468                     0.183   38        1   H1  -0.027996
#      443                     0.955   33        1   H1  -0.403562
#      463                     0.258   37        0   H1  -1.029505
#      131                     1.114   33        1   H1   0.034598
# ...                            ...  ...      ...  ...        ...
# H6   144                     0.237   23        0   H6   1.036107
#      726                     0.496   25        0   H6  -0.153185
#      328                     0.127   23        1   H6  -0.591345
#      497                     0.547   25        0   H6  -1.248585
#      232                     0.583   22        0   H6  -1.311179
#
#           BloodPressure_S     BMI_S
# AGEs
# H1   16          0.770014  1.752428
#      468        -3.572597 -0.252897
#      443         0.046245 -0.189437
#      463         0.459827 -0.557503
#      131        -0.677523  0.165937
# ...                   ...       ...
# H6   144        -0.367337  0.102477
#      726         0.459827  0.521311
#      328         0.873409  1.714352
#      497         0.149641 -0.240205
#      232         0.563223 -0.836725
#
# [540 rows x 13 columns]

# %%
df_train = df_train.droplevel(level=0)

# %%
df_test = df_sub.drop(index=df_train.index, axis=0)

# %%
df_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 20             3      126             88             41      235  39.3
# 23             9      119             80             35        0  29.0
# 35             4      103             60             33      192  24.0
# 46             1      146             56              0        0  29.7
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome AGEs  Glucose_S  BloodPressure_S  \
# 1                       0.351   31        0   H1  -1.123396        -0.160546
# 20                      0.704   27        0   H6   0.159787         0.976805
# 23                      0.263   29        1   H6  -0.059293         0.563223
# 35                      0.966   33        0   H1  -0.560048        -0.470732
# 46                      0.564   29        0   H6   0.785730        -0.677523
# ..                        ...  ...      ...  ...        ...              ...
# 762                     0.142   33        0   H1  -0.998208        -0.367337
# 763                     0.171   63        0   H4  -0.622642         0.356432
# 765                     0.245   30        0   H1   0.003301         0.149641
# 766                     0.349   47        1   H2   0.159787        -0.470732
# 767                     0.315   23        0   H6  -0.873019         0.046245
#
#         BMI_S
# 1   -0.684422
# 20   0.927452
# 23  -0.379816
# 35  -1.014412
# 46  -0.290972
# ..        ...
# 762 -1.204791
# 763  0.115169
# 765 -0.735190
# 766 -0.240205
# 767 -0.202129
#
# [135 rows x 13 columns]

# %%
GB_model = GaussianNB().fit(X=df_train[col_x_S], y=df_train["Outcome"])

# %%
df_test["pred"] = GB_model.predict(X=df_test[col_x_S])

# %%
df_test["pred"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
GB_model.predict_proba(X=df_test[col_x])
# Out:
# array([[0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [2.8063e-320, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000],
#        [0.0000e+000, 1.0000e+000]])

# %%
GB_f1 = f1_score(y_pred=df_test["pred"], y_true=df_test["Outcome"])

# %%
GB_f1
# Out:
# 0.5333333333333333

# %%
RF_model = RandomForestClassifier(n_estimators=10, min_samples_leaf=10, random_state=1234).fit(X=df_train[col_x_S], y=df_train["Outcome"])

# %%
df_test["pred"] = RF_model.predict(X=df_test[col_x_S])

# %%
RF_model.predict_proba(X=df_test[col_x_S])
# Out:
# array([[0.82426151, 0.17573849],
#        [0.65898628, 0.34101372],
#        [0.80802923, 0.19197077],
#        [0.97348777, 0.02651223],
#        [0.68920657, 0.31079343],
#        [0.96960623, 0.03039377],
#        [0.94011905, 0.05988095],
#        [0.97679739, 0.02320261],
#        [0.57651246, 0.42348754],
#        [0.82193778, 0.17806222],
#        [0.62643469, 0.37356531],
#        [0.76253932, 0.23746068],
#        [0.8357004 , 0.1642996 ],
#        [0.4348041 , 0.5651959 ],
#        [0.84936637, 0.15063363],
#        [0.25061228, 0.74938772],
#        [0.65428328, 0.34571672],
#        [0.80537145, 0.19462855],
#        [0.88503823, 0.11496177],
#        [0.9622549 , 0.0377451 ],
#        [0.4834002 , 0.5165998 ],
#        [0.68492913, 0.31507087],
#        [0.70627684, 0.29372316],
#        [0.48665225, 0.51334775],
#        [0.51335489, 0.48664511],
#        [0.975     , 0.025     ],
#        [0.6753991 , 0.3246009 ],
#        [0.96805556, 0.03194444],
#        [0.97463768, 0.02536232],
#        [0.98333333, 0.01666667],
#        [0.68652222, 0.31347778],
#        [0.4711392 , 0.5288608 ],
#        [0.69050325, 0.30949675],
#        [0.68516352, 0.31483648],
#        [0.90133038, 0.09866962],
#        [0.3476609 , 0.6523391 ],
#        [0.81597752, 0.18402248],
#        [0.8734638 , 0.1265362 ],
#        [0.74684348, 0.25315652],
#        [0.64514104, 0.35485896],
#        [0.66561702, 0.33438298],
#        [0.44310372, 0.55689628],
#        [0.26772682, 0.73227318],
#        [0.96666667, 0.03333333],
#        [0.84730072, 0.15269928],
#        [0.46430132, 0.53569868],
#        [0.71721467, 0.28278533],
#        [0.74448203, 0.25551797],
#        [0.75015693, 0.24984307],
#        [0.97396078, 0.02603922],
#        [0.67837959, 0.32162041],
#        [0.9200995 , 0.0799005 ],
#        [0.25061228, 0.74938772],
#        [0.56201789, 0.43798211],
#        [0.86823451, 0.13176549],
#        [0.9722973 , 0.0277027 ],
#        [0.80822341, 0.19177659],
#        [0.54523272, 0.45476728],
#        [0.88657669, 0.11342331],
#        [0.46931565, 0.53068435],
#        [0.35114338, 0.64885662],
#        [0.4711392 , 0.5288608 ],
#        [0.91044133, 0.08955867],
#        [0.97027914, 0.02972086],
#        [0.9722973 , 0.0277027 ],
#        [0.97854244, 0.02145756],
#        [0.64907825, 0.35092175],
#        [0.81870424, 0.18129576],
#        [0.69201984, 0.30798016],
#        [0.90169872, 0.09830128],
#        [0.65434947, 0.34565053],
#        [0.7209399 , 0.2790601 ],
#        [0.48031679, 0.51968321],
#        [0.59586556, 0.40413444],
#        [0.60799754, 0.39200246],
#        [0.73615986, 0.26384014],
#        [0.39375077, 0.60624923],
#        [0.87926754, 0.12073246],
#        [0.44624131, 0.55375869],
#        [0.48642986, 0.51357014],
#        [0.89200686, 0.10799314],
#        [0.74526839, 0.25473161],
#        [0.70040193, 0.29959807],
#        [0.85380659, 0.14619341],
#        [0.30961423, 0.69038577],
#        [0.54982862, 0.45017138],
#        [0.65187519, 0.34812481],
#        [0.58404318, 0.41595682],
#        [0.84432988, 0.15567012],
#        [0.97401961, 0.02598039],
#        [0.77560755, 0.22439245],
#        [0.8804731 , 0.1195269 ],
#        [0.70705795, 0.29294205],
#        [0.37000232, 0.62999768],
#        [0.873069  , 0.126931  ],
#        [0.57989613, 0.42010387],
#        [0.47378929, 0.52621071],
#        [0.84642888, 0.15357112],
#        [0.96960623, 0.03039377],
#        [0.60941705, 0.39058295],
#        [0.83691584, 0.16308416],
#        [0.78310159, 0.21689841],
#        [0.52149196, 0.47850804],
#        [0.85024644, 0.14975356],
#        [0.62796778, 0.37203222],
#        [0.67407468, 0.32592532],
#        [0.80647418, 0.19352582],
#        [0.90090917, 0.09909083],
#        [0.72391755, 0.27608245],
#        [0.72184702, 0.27815298],
#        [0.30812554, 0.69187446],
#        [0.36541137, 0.63458863],
#        [0.34415738, 0.65584262],
#        [0.91183022, 0.08816978],
#        [0.25061228, 0.74938772],
#        [0.4175282 , 0.5824718 ],
#        [0.79356252, 0.20643748],
#        [0.47046088, 0.52953912],
#        [0.67561466, 0.32438534],
#        [0.69360961, 0.30639039],
#        [0.87678348, 0.12321652],
#        [0.30758381, 0.69241619],
#        [0.65494744, 0.34505256],
#        [0.38383174, 0.61616826],
#        [0.85274146, 0.14725854],
#        [0.71084763, 0.28915237],
#        [0.84789248, 0.15210752],
#        [0.42766489, 0.57233511],
#        [0.75101732, 0.24898268],
#        [0.9403905 , 0.0596095 ],
#        [0.9722973 , 0.0277027 ],
#        [0.67551232, 0.32448768],
#        [0.84036162, 0.15963838],
#        [0.63015876, 0.36984124],
#        [0.82338933, 0.17661067]])

# %%
RF_f1 = f1_score(y_pred=df_test["pred"], y_true=df_test["Outcome"])

# %%
RF_f1
# Out:
# 0.4657534246575343

# %%
abs(GB_f1-RF_f1).round(3)
# Out:
# 0.068
