# %%
import pandas as pd

# %%
bike = pd.read_csv("data/bike.csv")

# %%
bike.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike_sub = bike.sample(n=4, random_state=123)

# %%
bike_sub
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6495  2012-03-07 21:00:00       1        0           1        1  18.04
# 7050  2012-04-12 03:00:00       2        0           1        1  13.12
# 558   2011-02-06 10:00:00       1        0           0        1  12.30
# 5085  2011-12-05 23:00:00       4        0           1        2  18.86
#
#        atemp  humidity  windspeed  casual  registered  count
# 6495  21.970        62    16.9979      11         177    188
# 7050  15.150        61    16.9979       2           3      5
# 558   14.395        52    16.9979      15          74     89
# 5085  22.725        88     8.9981       8          54     62

# %%
bike_sub.reset_index()
# Out:
#    index             datetime  season  holiday  workingday  weather   temp  \
# 0   6495  2012-03-07 21:00:00       1        0           1        1  18.04
# 1   7050  2012-04-12 03:00:00       2        0           1        1  13.12
# 2    558  2011-02-06 10:00:00       1        0           0        1  12.30
# 3   5085  2011-12-05 23:00:00       4        0           1        2  18.86
#
#     atemp  humidity  windspeed  casual  registered  count
# 0  21.970        62    16.9979      11         177    188
# 1  15.150        61    16.9979       2           3      5
# 2  14.395        52    16.9979      15          74     89
# 3  22.725        88     8.9981       8          54     62

# %%
bike_sub.reset_index(drop=True)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2012-03-07 21:00:00       1        0           1        1  18.04  21.970
# 1  2012-04-12 03:00:00       2        0           1        1  13.12  15.150
# 2  2011-02-06 10:00:00       1        0           0        1  12.30  14.395
# 3  2011-12-05 23:00:00       4        0           1        2  18.86  22.725
#
#    humidity  windspeed  casual  registered  count
# 0        62    16.9979      11         177    188
# 1        61    16.9979       2           3      5
# 2        52    16.9979      15          74     89
# 3        88     8.9981       8          54     62

# %%
bike_sub = bike_sub.reset_index(drop=True)

# %%
bike_sub
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2012-03-07 21:00:00       1        0           1        1  18.04  21.970
# 1  2012-04-12 03:00:00       2        0           1        1  13.12  15.150
# 2  2011-02-06 10:00:00       1        0           0        1  12.30  14.395
# 3  2011-12-05 23:00:00       4        0           1        2  18.86  22.725
#
#    humidity  windspeed  casual  registered  count
# 0        62    16.9979      11         177    188
# 1        61    16.9979       2           3      5
# 2        52    16.9979      15          74     89
# 3        88     8.9981       8          54     62

# %%
bike_sub = bike_sub.set_index("datetime")

# %%
bike_sub
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-03-07 21:00:00       1        0           1        1  18.04  21.970
# 2012-04-12 03:00:00       2        0           1        1  13.12  15.150
# 2011-02-06 10:00:00       1        0           0        1  12.30  14.395
# 2011-12-05 23:00:00       4        0           1        2  18.86  22.725
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-03-07 21:00:00        62    16.9979      11         177    188
# 2012-04-12 03:00:00        61    16.9979       2           3      5
# 2011-02-06 10:00:00        52    16.9979      15          74     89
# 2011-12-05 23:00:00        88     8.9981       8          54     62

# %%
bike_sub.reset_index()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2012-03-07 21:00:00       1        0           1        1  18.04  21.970
# 1  2012-04-12 03:00:00       2        0           1        1  13.12  15.150
# 2  2011-02-06 10:00:00       1        0           0        1  12.30  14.395
# 3  2011-12-05 23:00:00       4        0           1        2  18.86  22.725
#
#    humidity  windspeed  casual  registered  count
# 0        62    16.9979      11         177    188
# 1        61    16.9979       2           3      5
# 2        52    16.9979      15          74     89
# 3        88     8.9981       8          54     62

# %%
bike_1 = bike.iloc[:3,:4]
bike_2 = bike.iloc[5:8,:4]
print(len(bike_1))
print(len(bike_2))
# Out:
# 3
# 3

# %%
bike_1
# Out:
#               datetime  season  holiday  workingday
# 0  2011-01-01 00:00:00       1        0           0
# 1  2011-01-01 01:00:00       1        0           0
# 2  2011-01-01 02:00:00       1        0           0

# %%
bike_2
# Out:
#               datetime  season  holiday  workingday
# 5  2011-01-01 05:00:00       1        0           0
# 6  2011-01-01 06:00:00       1        0           0
# 7  2011-01-01 07:00:00       1        0           0

# %%
pd.concat([bike_1,bike_2])
# Out:
#               datetime  season  holiday  workingday
# 0  2011-01-01 00:00:00       1        0           0
# 1  2011-01-01 01:00:00       1        0           0
# 2  2011-01-01 02:00:00       1        0           0
# 5  2011-01-01 05:00:00       1        0           0
# 6  2011-01-01 06:00:00       1        0           0
# 7  2011-01-01 07:00:00       1        0           0

# %%
pd.concat([bike_1,bike_2],axis=1)
# Out:
#               datetime  season  holiday  workingday             datetime  \
# 0  2011-01-01 00:00:00     1.0      0.0         0.0                  NaN
# 1  2011-01-01 01:00:00     1.0      0.0         0.0                  NaN
# 2  2011-01-01 02:00:00     1.0      0.0         0.0                  NaN
# 5                  NaN     NaN      NaN         NaN  2011-01-01 05:00:00
# 6                  NaN     NaN      NaN         NaN  2011-01-01 06:00:00
# 7                  NaN     NaN      NaN         NaN  2011-01-01 07:00:00
#
#    season  holiday  workingday
# 0     NaN      NaN         NaN
# 1     NaN      NaN         NaN
# 2     NaN      NaN         NaN
# 5     1.0      0.0         0.0
# 6     1.0      0.0         0.0
# 7     1.0      0.0         0.0

# %%
pd.concat([bike_1,bike_2.reset_index(drop=True)],axis=1)
# Out:
#               datetime  season  holiday  workingday             datetime  \
# 0  2011-01-01 00:00:00       1        0           0  2011-01-01 05:00:00
# 1  2011-01-01 01:00:00       1        0           0  2011-01-01 06:00:00
# 2  2011-01-01 02:00:00       1        0           0  2011-01-01 07:00:00
#
#    season  holiday  workingday
# 0       1        0           0
# 1       1        0           0
# 2       1        0           0

# %%
pd.concat([bike_1.reset_index(drop=True),
           bike_2.reset_index(drop=True)],
          axis=1)
# Out:
#               datetime  season  holiday  workingday             datetime  \
# 0  2011-01-01 00:00:00       1        0           0  2011-01-01 05:00:00
# 1  2011-01-01 01:00:00       1        0           0  2011-01-01 06:00:00
# 2  2011-01-01 02:00:00       1        0           0  2011-01-01 07:00:00
#
#    season  holiday  workingday
# 0       1        0           0
# 1       1        0           0
# 2       1        0           0

# %%
df_A = pd.read_csv("data/join_data_group_members.csv")

# %%
df_B = pd.read_csv("data/join_data_member_room.csv")

# %%
print(df_A)
# Out:
#           team    No member
# 0        TWICE  1414     미나
# 1        TWICE  1462     나연
# 2        TWICE  1178     다현
# 3        TWICE  1525     정연
# 4        TWICE  1194     지효
# 5        TWICE  1937     채연
# 6        TWICE  1817     모모
# 7        TWICE  1117     쯔위
# 8        TWICE  1298     사나
# 9   Red Velvet  1228    아이린
# 10  Red Velvet  1243     웬디
# 11  Red Velvet  1013     슬기
# 12  Red Velvet  1373     조이
# 13  Red Velvet  1664     예리

# %%
print(df_B)
# Out:
#    floor  room name
# 0      3  3G-A   미나
# 1      3  3G-B   나연
# 2      3  3G-C   다현
# 3      4  4G-A   정연
# 4      4  4G-B   지효
# 5      4  4G-C   채연
# 6      5  5G-A   모모
# 7      5  5G-B   쯔위
# 8      5  5G-C   사나

# %%
print(df_A.shape)
print(df_B.shape)
# Out:
# (14, 3)
# (9, 3)

# %%
df_inner_join = pd.merge(left=df_A, right = df_B,
        left_on = "member", right_on = "name",
        how = "inner")

# %%
df_inner_join
# Out:
#     team    No member  floor  room name
# 0  TWICE  1414     미나      3  3G-A   미나
# 1  TWICE  1462     나연      3  3G-B   나연
# 2  TWICE  1178     다현      3  3G-C   다현
# 3  TWICE  1525     정연      4  4G-A   정연
# 4  TWICE  1194     지효      4  4G-B   지효
# 5  TWICE  1937     채연      4  4G-C   채연
# 6  TWICE  1817     모모      5  5G-A   모모
# 7  TWICE  1117     쯔위      5  5G-B   쯔위
# 8  TWICE  1298     사나      5  5G-C   사나

# %%
df_inner_join.shape
# Out:
# (9, 6)

# %%
df_left_join = pd.merge(left=df_A, right = df_B,
        left_on = "member", right_on = "name",
        how = "left")

# %%
df_left_join
# Out:
#           team    No member  floor  room name
# 0        TWICE  1414     미나    3.0  3G-A   미나
# 1        TWICE  1462     나연    3.0  3G-B   나연
# 2        TWICE  1178     다현    3.0  3G-C   다현
# 3        TWICE  1525     정연    4.0  4G-A   정연
# 4        TWICE  1194     지효    4.0  4G-B   지효
# 5        TWICE  1937     채연    4.0  4G-C   채연
# 6        TWICE  1817     모모    5.0  5G-A   모모
# 7        TWICE  1117     쯔위    5.0  5G-B   쯔위
# 8        TWICE  1298     사나    5.0  5G-C   사나
# 9   Red Velvet  1228    아이린    NaN   NaN  NaN
# 10  Red Velvet  1243     웬디    NaN   NaN  NaN
# 11  Red Velvet  1013     슬기    NaN   NaN  NaN
# 12  Red Velvet  1373     조이    NaN   NaN  NaN
# 13  Red Velvet  1664     예리    NaN   NaN  NaN

# %%
df_right_join = pd.merge(left=df_A, right = df_B,
        left_on = "member", right_on = "name",
        how = "right")

# %%
df_right_join
# Out:
#     team    No member  floor  room name
# 0  TWICE  1414     미나      3  3G-A   미나
# 1  TWICE  1462     나연      3  3G-B   나연
# 2  TWICE  1178     다현      3  3G-C   다현
# 3  TWICE  1525     정연      4  4G-A   정연
# 4  TWICE  1194     지효      4  4G-B   지효
# 5  TWICE  1937     채연      4  4G-C   채연
# 6  TWICE  1817     모모      5  5G-A   모모
# 7  TWICE  1117     쯔위      5  5G-B   쯔위
# 8  TWICE  1298     사나      5  5G-C   사나

# %%
df_outer_join = pd.merge(left=df_A, right = df_B,
        left_on = "member", right_on = "name",
        how = "outer")

# %%
df_outer_join
# Out:
#           team    No member  floor  room name
# 0        TWICE  1414     미나    3.0  3G-A   미나
# 1        TWICE  1462     나연    3.0  3G-B   나연
# 2        TWICE  1178     다현    3.0  3G-C   다현
# 3        TWICE  1525     정연    4.0  4G-A   정연
# 4        TWICE  1194     지효    4.0  4G-B   지효
# 5        TWICE  1937     채연    4.0  4G-C   채연
# 6        TWICE  1817     모모    5.0  5G-A   모모
# 7        TWICE  1117     쯔위    5.0  5G-B   쯔위
# 8        TWICE  1298     사나    5.0  5G-C   사나
# 9   Red Velvet  1228    아이린    NaN   NaN  NaN
# 10  Red Velvet  1243     웬디    NaN   NaN  NaN
# 11  Red Velvet  1013     슬기    NaN   NaN  NaN
# 12  Red Velvet  1373     조이    NaN   NaN  NaN
# 13  Red Velvet  1664     예리    NaN   NaN  NaN

# %%
#문제 1
#문제가 A를 B에 left join한다고 하였는데 
#이 때 A, B의 선후 관계를 어떻게 정의하는가?

# %%
df_A = pd.read_csv("data/join_data_group_members.csv")
df_B = pd.read_csv("data/join_data_member_room.csv")

# %%
df_B.head(2)
# Out:
#    floor  room name
# 0      3  3G-A   미나
# 1      3  3G-B   나연

# %%
df_A.head(2)
# Out:
#     team    No member
# 0  TWICE  1414     미나
# 1  TWICE  1462     나연

# %%
df_left_join = pd.merge(left = df_A, right = df_B,
                       left_on = "member", right_on = "name",
                       how = "left")

# %%
df_left_join
# Out:
#           team    No member  floor  room name
# 0        TWICE  1414     미나    3.0  3G-A   미나
# 1        TWICE  1462     나연    3.0  3G-B   나연
# 2        TWICE  1178     다현    3.0  3G-C   다현
# 3        TWICE  1525     정연    4.0  4G-A   정연
# 4        TWICE  1194     지효    4.0  4G-B   지효
# 5        TWICE  1937     채연    4.0  4G-C   채연
# 6        TWICE  1817     모모    5.0  5G-A   모모
# 7        TWICE  1117     쯔위    5.0  5G-B   쯔위
# 8        TWICE  1298     사나    5.0  5G-C   사나
# 9   Red Velvet  1228    아이린    NaN   NaN  NaN
# 10  Red Velvet  1243     웬디    NaN   NaN  NaN
# 11  Red Velvet  1013     슬기    NaN   NaN  NaN
# 12  Red Velvet  1373     조이    NaN   NaN  NaN
# 13  Red Velvet  1664     예리    NaN   NaN  NaN

# %%
((df_left_join.isna().sum(axis=1))/(df_left_join.isna().sum(axis=1))).sum()
# Out:
# 5.0

# %%
#문제 2

# %%
bike = pd.read_csv("data/bike.csv")

# %%
bike.shape
# Out:
# (10886, 13)

# %%
bike.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike["season"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10881    4
# 10882    4
# 10883    4
# 10884    4
# 10885    4
# Name: season, Length: 10886, dtype: int64

# %%
bike["hour"]=pd.to_datetime(bike["datetime"]).dt.hour

# %%
bike_winter_12 = bike[pd.to_datetime(bike["datetime"]).dt.month == 12]

# %%
bike_winter_1 = bike[pd.to_datetime(bike["datetime"]).dt.month == 1]

# %%
bike_winter_2 = bike[pd.to_datetime(bike["datetime"]).dt.month == 2]

# %%
bike_summer_6 = bike[pd.to_datetime(bike["datetime"]).dt.month == 6]
bike_summer_7 = bike[pd.to_datetime(bike["datetime"]).dt.month == 7]
bike_summer_8 = bike[pd.to_datetime(bike["datetime"]).dt.month == 8]

# %%
bike_winter = pd.merge(left = bike_winter_1, right = bike_winter_12,
                      how="outer")

# %%
bike_winter.shape
# Out:
# (1796, 13)

# %%
bike_winter = pd.merge(left = bike_winter, right = bike_winter_2,
                      how="outer")

# %%
bike_winter.shape
# Out:
# (2697, 13)

# %%
bike_summer = pd.merge(left = bike_summer_6, right = bike_summer_7,
                      how="outer")

# %%
bike_summer = pd.merge(left = bike_summer, right = bike_summer_8,
                      how="outer")

# %%
bike_summer.shape
# Out:
# (2736, 13)

# %%
bike_winter.groupby("hour")["registered"].mean()
# Out:
# hour
# 0      31.026549
# 1      19.973451
# 2      14.738739
# 3       7.489796
# 4       3.752381
# 5      13.000000
# 6      48.203540
# 7     139.823009
# 8     275.557522
# 9     158.150442
# 10     97.522124
# 11    114.194690
# 12    144.482456
# 13    145.078947
# 14    131.692982
# 15    140.614035
# 16    178.859649
# 17    273.017544
# 18    251.991228
# 19    177.903509
# 20    126.368421
# 21     96.166667
# 22     72.842105
# 23     48.333333
# Name: registered, dtype: float64

# %%
bike_summer.groupby("hour")["registered"].mean()
# Out:
# hour
# 0      59.456140
# 1      35.166667
# 2      23.412281
# 3      10.535088
# 4       6.649123
# 5      22.315789
# 6      91.184211
# 7     251.298246
# 8     381.026316
# 9     209.105263
# 10    146.956140
# 11    169.543860
# 12    211.078947
# 13    203.578947
# 14    186.561404
# 15    195.157895
# 16    274.500000
# 17    466.166667
# 18    446.780702
# 19    331.842105
# 20    252.473684
# 21    193.324561
# 22    148.254386
# 23    100.078947
# Name: registered, dtype: float64

# %%
(bike_winter.groupby("hour")["registered"].mean() - bike_summer.groupby("hour")["registered"].mean()).abs().idxmax()
# Out:
# 18

# %%
#season을 기준으로 계절을 나누는 경우
bike = pd.read_csv("data/bike.csv")
bike["hour"]=pd.to_datetime(bike["datetime"]).dt.hour

# %%
bike_summer = bike[bike["season"]==2]

# %%
bike_winter = bike[bike["season"]==4]

# %%
(bike_summer.groupby("hour")["registered"].mean().reset_index() - bike_winter.groupby("hour")["registered"].mean().reset_index()).abs()
# Out:
#     hour  registered
# 0      0    4.070175
# 1      0    3.368421
# 2      0    1.210526
# 3      0    0.696429
# 4      0    1.034622
# 5      0    2.780702
# 6      0    2.350877
# 7      0    5.964912
# 8      0   22.210526
# 9      0   16.885965
# 10     0   15.368421
# 11     0   11.403509
# 12     0   17.561404
# 13     0   17.140351
# 14     0   20.043860
# 15     0   24.473684
# 16     0   18.956140
# 17     0    9.464912
# 18     0   26.947368
# 19     0   30.973684
# 20     0   22.412281
# 21     0   16.263158
# 22     0   13.263158
# 23     0    2.333333

# %%
(bike_summer.groupby("hour")["registered"].mean() - bike_winter.groupby("hour")["registered"].mean()).abs().idxmax()
# Out:
# 19

# %%
#선생님의 답안

# %%
#season을 기준으로 계절을 나누는 경우
bike = pd.read_csv("data/bike.csv")
bike["hour"]=pd.to_datetime(bike["datetime"]).dt.hour

# %%
bike_s2 = bike.loc[bike["season"] ==2,]
bike_s4 = bike.loc[bike["season"] ==4,]
print(bike_s2["season"].unique())
print(bike_s4["season"].unique())
# Out:
# [2]
# [4]

# %%
bike_s2_agg = bike_s2.groupby("hour")["registered"].mean().reset_index()
bike_s4_agg = bike_s4.groupby("hour")["registered"].mean().reset_index()

# %%
bike_s2_agg.head()
# Out:
#    hour  registered
# 0     0   45.947368
# 1     1   27.473684
# 2     2   17.763158
# 3     3    8.419643
# 4     4    5.053097

# %%
bike_s4_agg.head()
# Out:
#    hour  registered
# 0     0   50.017544
# 1     1   30.842105
# 2     2   18.973684
# 3     3    9.116071
# 4     4    6.087719

# %%
bike_agg_bind = pd.concat([bike_s2_agg, bike_s4_agg], axis=1)

# %%
bike_agg_bind.head()
# Out:
#    hour  registered  hour  registered
# 0     0   45.947368     0   50.017544
# 1     1   27.473684     1   30.842105
# 2     2   17.763158     2   18.973684
# 3     3    8.419643     3    9.116071
# 4     4    5.053097     4    6.087719

# %%
#hour가 중복이니 제거하자
bike_agg_bind = bike_agg_bind.iloc[:,[0,1,3]]
bike_agg_bind.head()
# Out:
#    hour  registered  registered
# 0     0   45.947368   50.017544
# 1     1   27.473684   30.842105
# 2     2   17.763158   18.973684
# 3     3    8.419643    9.116071
# 4     4    5.053097    6.087719

# %%
bike_agg_bind.columns=["hour","reg_s2","reg_s4"]

# %%
bike_agg_bind.head(2)
# Out:
#    hour     reg_s2     reg_s4
# 0     0  45.947368  50.017544
# 1     1  27.473684  30.842105

# %%
bike_agg_bind["diff"] = bike_agg_bind["reg_s2"] - bike_agg_bind["reg_s4"]
bike_agg_bind.head(2)
# Out:
#    hour     reg_s2     reg_s4      diff
# 0     0  45.947368  50.017544 -4.070175
# 1     1  27.473684  30.842105 -3.368421

# %%
bike_agg_bind.iloc[[bike_agg_bind["diff"].idxmax()],]
# Out:
#     hour      reg_s2      reg_s4       diff
# 19    19  302.298246  271.324561  30.973684

# %%
#문제 3

# %%
#선생님 풀이

# %%
import pandas as pd
bike = pd.read_csv("data/bike.csv")

# %%
bike.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
bike["hour"] = pd.to_datetime(bike["datetime"]).dt.hour
bike["date"] = pd.to_datetime(bike["datetime"]).dt.date

# %%
bike_h100 = bike.groupby("date")["humidity"].max().reset_index()

# %%
bike_h100.head()
# Out:
#          date  humidity
# 0  2011-01-01        94
# 1  2011-01-02       100
# 2  2011-01-03        69
# 3  2011-01-04        74
# 4  2011-01-05        74

# %%
bike_h100 = bike_h100.loc[bike_h100["humidity"]==100,]

# %%
bike_h100.head()
# Out:
#           date  humidity
# 1   2011-01-02       100
# 20  2011-02-02       100
# 23  2011-02-05       100
# 25  2011-02-07       100
# 42  2011-03-05       100

# %%
len(bike_h100)
# Out:
# 40

# %%
bike_join = pd.merge(left=bike, right = bike_h100,
                    left_on = "date", right_on = "date",
                    how="inner")

# %%
bike_join.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-02 00:00:00       1        0           0        2  18.86  22.725
# 1  2011-01-02 01:00:00       1        0           0        2  18.04  21.970
# 2  2011-01-02 02:00:00       1        0           0        2  17.22  21.210
# 3  2011-01-02 03:00:00       1        0           0        2  18.86  22.725
# 4  2011-01-02 04:00:00       1        0           0        2  18.86  22.725
#
#    humidity_x  windspeed  casual  registered  count  hour        date  \
# 0          88    19.9995       4          13     17     0  2011-01-02
# 1          94    16.9979       1          16     17     1  2011-01-02
# 2         100    19.0012       1           8      9     2  2011-01-02
# 3          94    12.9980       2           4      6     3  2011-01-02
# 4          94    12.9980       2           1      3     4  2011-01-02
#
#    humidity_y
# 0         100
# 1         100
# 2         100
# 3         100
# ...

# %%
bike_join_temp_up30 = bike_join.loc[bike_join["temp"]>30,]

# %%
bike_join_temp_up30
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 297  2011-04-11 15:00:00       2        0           1        1  30.34  33.335
# 298  2011-04-11 16:00:00       2        0           1        1  30.34  33.335
# 299  2011-04-11 17:00:00       2        0           1        1  30.34  33.335
# 487  2011-06-17 13:00:00       2        0           1        1  30.34  34.090
# 488  2011-06-17 14:00:00       2        0           1        1  31.16  34.850
# 489  2011-06-17 15:00:00       2        0           1        1  31.98  34.850
# 490  2011-06-17 16:00:00       2        0           1        1  31.16  34.090
# 491  2011-06-17 17:00:00       2        0           1        3  31.16  34.090
# 492  2011-06-17 18:00:00       2        0           1        3  31.16  34.090
# 560  2011-09-09 15:00:00       3        0           1        1  30.34  34.850
# 561  2011-09-09 16:00:00       3        0           1        1  30.34  34.850
# ...

# %%
bike_join_temp_up30["count"].mean()
# Out:
# 338.75
